# %% [markdown]
# # PPE Classification v6.3 — 균등 샘플링 + MobileNetV3Large
# ## 안전모 / 안전조끼 착용 여부 분류 (통합 모델)
#
# ### 파일명 라벨 규칙
# ```
# 파일명 형식: XXXX_HV.jpg
#   0001_00.jpg → helmet=0, vest=0
#   0002_10.jpg → helmet=1, vest=0
#   0003_01.jpg → helmet=0, vest=1
#   0004_11.jpg → helmet=1, vest=1
# ```
#
# ### v7 → v7.1 변경사항
# ```
# 1. Loss 함수 변경: Focal Loss → Binary Crossentropy
#    균등 샘플링(각 1000장)으로 클래스 균형이 맞춰져 Focal Loss 불필요
# 2. 클래스 가중치 완전 제거
#    compute_class_weight, sample_weight 코드 삭제

# %% [markdown]
# ---
# ## 1. 모듈 로딩

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import glob
import cv2
import os
import time
import random
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

print("NumPy Version      :", np.__version__)
print("TensorFlow Version :", tf.__version__)
# Out:
# NumPy Version      : 2.4.4
# TensorFlow Version : 2.21.0

# %% [markdown]
# ---
# ## 2. 실행 환경 감지

# %%
try:
    import google.colab
    colab = True
    print("환경: Google Colab")
except ImportError:
    colab = False
    print("환경: 로컬 (VS Code / Jupyter)")
# Out:
# 환경: 로컬 (VS Code / Jupyter)

# %% [markdown]
# ---
# ## 3. 경로 설정
# ### ★ 로컬 실행 시 `LOCAL_DATA_PATH`, `LOCAL_SAVE_PATH`만 수정

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# ============================================================
# #  ★ 로컬 실행 시 아래 두 경로를 본인 환경에 맞게 수정하세요
# ============================================================
LOCAL_DATA_PATH = r'C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled'   # 이미지 폴더
LOCAL_SAVE_PATH = r'C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled'      # 모델 저장 폴더
# ============================================================

if colab:
    # ── Colab: Drive 마운트 후 zip 압축 해제 ──
    # from google.colab import drive
    # drive.mount('/content/drive')
    print('Google Drive 마운트 완료')

    # !unzip -q -o /content/drive/MyDrive/Safe/Result.zip -d /content/
    files_path = '/content/drive/MyDrive/프로젝트/Result/Result'
    save_dir   = '/content/drive/MyDrive/프로젝트/Result/Result'
else:
    # ── 로컬: 위에서 설정한 경로 사용 ──
    files_path = LOCAL_DATA_PATH
    save_dir   = LOCAL_SAVE_PATH

os.makedirs(save_dir, exist_ok=True)

print(f"\n데이터 경로 : {files_path}")
print(f"저장 경로   : {save_dir}")

# 경로 존재 여부 확인
if not os.path.exists(files_path):
    print(f"\n⚠️  경로를 찾을 수 없어요: {files_path}")
    print("   LOCAL_DATA_PATH 를 올바르게 수정해 주세요.")
else:
    img_count = len(glob.glob(files_path + '/*.*'))
    print(f"\n✅ 경로 확인 완료  ({img_count}개 파일 발견)")
# Out:
# 데이터 경로 : C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled
# 저장 경로   : C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled
#
# ✅ 경로 확인 완료  (3791개 파일 발견)

# %% [markdown]
# ---
# ## 4. 파일명 파싱 → 라벨 자동 생성

# %%
def parse_label_from_filename(filepath):
    """
    파일명에서 helmet / vest 라벨을 파싱한다.

    규칙: XXXX_HV.확장자
      H: 0=헬멧 미착용, 1=헬멧 착용
      V: 0=조끼 미착용, 1=조끼 착용

    Returns: [helmet, vest] 또는 파싱 실패 시 None
    """
    name = os.path.splitext(os.path.basename(filepath))[0]  # 확장자 제거

    if '_' not in name:
        print(f"[건너뜀] '_' 없는 파일명: {os.path.basename(filepath)}")
        return None

    label_str = name.split('_')[-1]  # '_' 뒤 마지막 부분

    if len(label_str) < 2:
        print(f"[건너뜀] 라벨 자리수 부족: {os.path.basename(filepath)}")
        return None

    try:
        helmet = int(label_str[0])
        vest   = int(label_str[1])
    except ValueError:
        print(f"[건너뜀] 숫자 아닌 라벨: {os.path.basename(filepath)}")
        return None

    if helmet not in (0, 1) or vest not in (0, 1):
        print(f"[건너뜀] 라벨은 0 또는 1이어야 함: {os.path.basename(filepath)}")
        return None

    return [helmet, vest]


# 파싱 테스트
test_cases = ['0001_00.jpg', '0002_10.jpg', '0003_01.jpg', '0004_11.jpg']
print("파일명 파싱 테스트")
print("-" * 40)
for tc in test_cases:
    lbl = parse_label_from_filename(tc)
    print(f"  {tc:15s} → helmet={lbl[0]}, vest={lbl[1]}")
# Out:
# 파일명 파싱 테스트
# ----------------------------------------
#   0001_00.jpg     → helmet=0, vest=0
#   0002_10.jpg     → helmet=1, vest=0
#   0003_01.jpg     → helmet=0, vest=1
#   0004_11.jpg     → helmet=1, vest=1

# %% [markdown]
# ---
# ## 6. 이미지 로딩 + 클래스별 균등 샘플링
# > 11/10/00: 각 1000장 랜덤 추출, 01: 전체 사용 (~904장)

# %%
# %%time
IMG_SIZE = 224
SAMPLE_PER_CLASS = 1000

all_files = sorted(
    glob.glob(files_path + '/*.jpg') +
    glob.glob(files_path + '/*.jpeg') +
    glob.glob(files_path + '/*.png')
)
print(f"전체 파일 수: {len(all_files)}개")


def resize_with_padding(img, size=224):
    h, w = img.shape[:2]
    scale = size / max(h, w)
    new_w, new_h = int(w * scale), int(h * scale)
    img_resized = cv2.resize(img, (new_w, new_h))
    canvas = np.zeros((size, size, 3), dtype=np.uint8)
    top  = (size - new_h) // 2
    left = (size - new_w) // 2
    canvas[top:top+new_h, left:left+new_w] = img_resized
    return canvas


# 1단계: 클래스별 분류
class_files = {'11': [], '10': [], '01': [], '00': []}
skipped = 0
for fpath in all_files:
    lbl = parse_label_from_filename(fpath)
    if lbl is None:
        skipped += 1
        continue
    class_files[f"{int(lbl[0])}{int(lbl[1])}"].append(fpath)

print(f"파싱 완료 (건너뜀: {skipped}장)")
for k, v in class_files.items():
    print(f"  {k} (helmet={k[0]}, vest={k[1]}): {len(v)}장")

# 2단계: 균등 샘플링
random.seed(42)
sampled_files = []
print(f"\n★ 클래스별 샘플링 (목표: 각 {SAMPLE_PER_CLASS}장, 부족 시 전체)")
for key in ['11', '10', '01', '00']:
    files = class_files[key]
    selected = files if len(files) <= SAMPLE_PER_CLASS else random.sample(files, SAMPLE_PER_CLASS)
    sampled_files.extend([(f, key) for f in selected])
    print(f"  {key}: {len(files)}장 → {len(selected)}장 선택")
print(f"총 샘플: {len(sampled_files)}장")

# 3단계: 로딩
images, labels, load_fail = [], [], 0
for fpath, key in sampled_files:
    img = cv2.imread(fpath, cv2.IMREAD_COLOR)
    if img is None:
        load_fail += 1
        continue
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = resize_with_padding(img, IMG_SIZE)
    images.append(img)
    labels.append([int(key[0]), int(key[1])])

images = np.array(images, dtype=np.uint8)
labels = np.array(labels, dtype=np.float32)
print(f"\n✅ 로딩 완료: {len(images)}장  (실패: {load_fail}장)")
print(f"images: {images.shape}  labels: {labels.shape}")
# Out:
# 전체 파일 수: 3791개
# 파싱 완료 (건너뜀: 0장)
#   11 (helmet=1, vest=1): 1000장
#   10 (helmet=1, vest=0): 1000장
#   01 (helmet=0, vest=1): 791장
#   00 (helmet=0, vest=0): 1000장
#
# ★ 클래스별 샘플링 (목표: 각 1000장, 부족 시 전체)
#   11: 1000장 → 1000장 선택
#   10: 1000장 → 1000장 선택
#   01: 791장 → 791장 선택
#   00: 1000장 → 1000장 선택
# 총 샘플: 3791장
#
# ✅ 로딩 완료: 3791장  (실패: 0장)
# images: (3791, 224, 224, 3)  labels: (3791, 2)
# CPU times: total: 2.8 s
# Wall time: 2.8 s

# %% [markdown]
# ---
# ## 7. 클래스 분포 확인

# %%
helmet_on  = int(labels[:, 0].sum())
helmet_off = len(labels) - helmet_on
vest_on    = int(labels[:, 1].sum())
vest_off   = len(labels) - vest_on

combos = {'00': 0, '10': 0, '01': 0, '11': 0}
for lbl in labels:
    combos[f"{int(lbl[0])}{int(lbl[1])}"] += 1

print("=== 클래스 분포 ===")
print(f"헬멧  착용(1): {helmet_on:5d}장   미착용(0): {helmet_off:5d}장")
print(f"조끼  착용(1): {vest_on  :5d}장   미착용(0): {vest_off  :5d}장")
print("\n=== 조합별 분포 ===")
for k, v in combos.items():
    print(f"  helmet={k[0]}, vest={k[1]}  →  {v:5d}장")

fig, axes = plt.subplots(1, 3, figsize=(14, 4))
axes[0].bar(['착용(1)', '미착용(0)'], [helmet_on,  helmet_off], color=['steelblue', 'tomato'])
axes[0].set_title('Helmet 분포')
axes[0].set_ylabel('이미지 수')
axes[1].bar(['착용(1)', '미착용(0)'], [vest_on,    vest_off],   color=['steelblue', 'tomato'])
axes[1].set_title('Vest 분포')
axes[2].bar(list(combos.keys()), list(combos.values()), color='mediumpurple')
axes[2].set_title('조합별 분포')
axes[2].set_xlabel('HV  (H=helmet, V=vest)')
plt.tight_layout()
plt.show()
# Out:
# === 클래스 분포 ===
# 헬멧  착용(1):  2000장   미착용(0):  1791장
# 조끼  착용(1):  1791장   미착용(0):  2000장
#
# === 조합별 분포 ===
#   helmet=0, vest=0  →   1000장
#   helmet=1, vest=0  →   1000장
#   helmet=0, vest=1  →    791장
#   helmet=1, vest=1  →   1000장
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\495743501.py:26: UserWarning: Glyph 52265 (\N{HANGUL SYLLABLE CAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\495743501.py:26: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\495743501.py:26: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\495743501.py:26: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\495743501.py:26: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\495743501.py:26: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\495743501.py:26: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\495743501.py:26: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\495743501.py:26: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\495743501.py:26: UserWarning: Glyph 54633 (\N{HANGUL SYLLABLE HAB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\495743501.py:26: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54252 (\N{HANGUL SYLLABLE PO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52265 (\N{HANGUL SYLLABLE CAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54633 (\N{HANGUL SYLLABLE HAB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ---
# ## 8. Train / Test 분리

# %%
train_data, test_data, train_labels, test_labels = train_test_split(
    images, labels,
    test_size    = 0.2,
    random_state = 128
)
print(f"train_data   : {train_data.shape}")
print(f"train_labels : {train_labels.shape}")
print(f"test_data    : {test_data.shape}")
print(f"test_labels  : {test_labels.shape}")
# Out:
# train_data   : (3032, 224, 224, 3)
# train_labels : (3032, 2)
# test_data    : (759, 224, 224, 3)
# test_labels  : (759, 2)

# %% [markdown]
# ---
# ## 9. 모델 생성 — MobileNetV3Large
# > 출력: sigmoid × 2 → [helmet_prob, vest_prob]

# %%
def build_model():
    inputs = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    base_model = tf.keras.applications.MobileNetV3Large(
        weights='imagenet', include_top=False,
        input_shape=(IMG_SIZE, IMG_SIZE, 3)
        # include_preprocessing=True (기본값)이 [0,255]를 알아서 처리
    )
    base_model.trainable = False
    x = base_model(inputs, training=False)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.3)(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    outputs = tf.keras.layers.Dense(2, activation='sigmoid', name='ppe_output')(x)

    return tf.keras.Model(inputs, outputs)

model = build_model()
print(f"모델 생성 완료  파라미터: {model.count_params():,}")
print("백본: MobileNetV3Large")
model.summary()
# Out:
# 모델 생성 완료  파라미터: 3,276,546
# 백본: MobileNetV3Large
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MobileNetV3Large (Functional)   │ (None, 7, 7, 960)      │     2,996,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 960)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       246,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ppe_output (Dense)              │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,276,546 (12.50 MB)
#  Trainable params: 279,682 (1.07 MB)
#  Non-trainable params: 2,996,864 (11.43 MB)

# %% [markdown]
# ---
# ## 10. 모델 컴파일 — Focal Loss

# %%
model.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss      = 'binary_crossentropy',
    metrics   = ['binary_accuracy']
)
print("컴파일 완료 (Binary Crossentropy)")
# Out:
# 컴파일 완료 (Binary Crossentropy)

# %% [markdown]
# ---
# ## 11. 학습 전 결과 시각화

# %%
def Make_Result_Plot(suptitle, data, true_labels, pred_probs, n=10, threshold=0.6):
    """
    true_labels : (N, 2)  [helmet, vest]
    pred_probs  : (N, 2)  [helmet_prob, vest_prob]
    """
    size = max(len(data) // n, 1)
    fig, axes = plt.subplots(2, 5, figsize=(20, 8))
    fig.suptitle(suptitle, fontsize=14)
    for idx in range(n):
        cnt   = min(idx * size + size // 2, len(data) - 1)
        ax    = axes[idx // 5, idx % 5]
        ax.imshow(data[cnt])
        h_true, v_true = int(true_labels[cnt][0]), int(true_labels[cnt][1])
        h_prob, v_prob = pred_probs[cnt][0],       pred_probs[cnt][1]
        h_pred = int(h_prob >= threshold)
        v_pred = int(v_prob >= threshold)
        color  = 'red' if (h_true != h_pred or v_true != v_pred) else 'black'
        ax.set_title(
            f"True H={h_true} V={v_true}\nPred H={h_pred}({h_prob:.2f}) V={v_pred}({v_prob:.2f})",
            fontsize=8, color=color
        )
        ax.axis('off')
    plt.tight_layout()
    plt.show()

y_out = model.predict(test_data)
Make_Result_Plot("Before Training", test_data, test_labels, y_out)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 370ms/step

# %% [markdown]
# ---
# ## 12. 콜백 설정

# %%
saved_model_name = os.path.join(save_dir, 'PPE_MobileNetV3Large.keras')

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        saved_model_name, save_best_only=True,
        monitor='val_binary_accuracy', mode='max', verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        patience             = 10,
        monitor              = 'val_binary_accuracy',
        restore_best_weights = True, verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5,
        patience=5, verbose=1
    )
]
print(f"모델 저장 경로: {saved_model_name}")
# Out:
# 모델 저장 경로: C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras

# %% [markdown]
# ---
# ## 13. 모델 학습
# > 클래스 가중치 + Focal Loss

# %%
# %%time

history = model.fit(
    train_data, train_labels,
    epochs          = 30,
    batch_size      = 32,
    callbacks       = callbacks,
    validation_data = (test_data, test_labels)
)
# Out:
# Epoch 1/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step - binary_accuracy: 0.6228 - loss: 0.7156
# Epoch 1: val_binary_accuracy improved from None to 0.81357, saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
#
# Epoch 1: finished saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 51s 428ms/step - binary_accuracy: 0.7032 - loss: 0.5840 - val_binary_accuracy: 0.8136 - val_loss: 0.4204 - learning_rate: 1.0000e-04
# Epoch 2/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - binary_accuracy: 0.8303 - loss: 0.3816
# Epoch 2: val_binary_accuracy improved from 0.81357 to 0.88538, saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
#
# Epoch 2: finished saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 40s 419ms/step - binary_accuracy: 0.8433 - loss: 0.3566 - val_binary_accuracy: 0.8854 - val_loss: 0.2997 - learning_rate: 1.0000e-04
# Epoch 3/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - binary_accuracy: 0.8618 - loss: 0.3091
# Epoch 3: val_binary_accuracy improved from 0.88538 to 0.90316, saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
#
# Epoch 3: finished saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 37s 387ms/step - binary_accuracy: 0.8732 - loss: 0.3008 - val_binary_accuracy: 0.9032 - val_loss: 0.2525 - learning_rate: 1.0000e-04
# Epoch 4/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - binary_accuracy: 0.8966 - loss: 0.2598
# Epoch 4: val_binary_accuracy improved from 0.90316 to 0.91173, saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
#
# Epoch 4: finished saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 37s 385ms/step - binary_accuracy: 0.8954 - loss: 0.2568 - val_binary_accuracy: 0.9117 - val_loss: 0.2339 - learning_rate: 1.0000e-04
# Epoch 5/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - binary_accuracy: 0.8971 - loss: 0.2503
# Epoch 5: val_binary_accuracy improved from 0.91173 to 0.91370, saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
#
# Epoch 5: finished saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 36s 380ms/step - binary_accuracy: 0.9024 - loss: 0.2388 - val_binary_accuracy: 0.9137 - val_loss: 0.2224 - learning_rate: 1.0000e-04
# Epoch 6/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - binary_accuracy: 0.9187 - loss: 0.2120
# Epoch 6: val_binary_accuracy did not improve from 0.91370
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 35s 368ms/step - binary_accuracy: 0.9162 - loss: 0.2148 - val_binary_accuracy: 0.9137 - val_loss: 0.2181 - learning_rate: 1.0000e-04
# Epoch 7/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - binary_accuracy: 0.9185 - loss: 0.2056
# Epoch 7: val_binary_accuracy improved from 0.91370 to 0.91568, saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
#
# Epoch 7: finished saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 36s 375ms/step - binary_accuracy: 0.9218 - loss: 0.2007 - val_binary_accuracy: 0.9157 - val_loss: 0.2096 - learning_rate: 1.0000e-04
# Epoch 8/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - binary_accuracy: 0.9307 - loss: 0.1858
# Epoch 8: val_binary_accuracy improved from 0.91568 to 0.91765, saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
#
# Epoch 8: finished saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 36s 376ms/step - binary_accuracy: 0.9284 - loss: 0.1864 - val_binary_accuracy: 0.9177 - val_loss: 0.2065 - learning_rate: 1.0000e-04
# Epoch 9/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - binary_accuracy: 0.9314 - loss: 0.1720
# Epoch 9: val_binary_accuracy improved from 0.91765 to 0.92161, saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
#
# Epoch 9: finished saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 36s 375ms/step - binary_accuracy: 0.9293 - loss: 0.1741 - val_binary_accuracy: 0.9216 - val_loss: 0.2025 - learning_rate: 1.0000e-04
# Epoch 10/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - binary_accuracy: 0.9331 - loss: 0.1585
# Epoch 10: val_binary_accuracy did not improve from 0.92161
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 35s 368ms/step - binary_accuracy: 0.9324 - loss: 0.1643 - val_binary_accuracy: 0.9209 - val_loss: 0.2024 - learning_rate: 1.0000e-04
# Epoch 11/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - binary_accuracy: 0.9432 - loss: 0.1568
# Epoch 11: val_binary_accuracy improved from 0.92161 to 0.92951, saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
#
# Epoch 11: finished saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 36s 375ms/step - binary_accuracy: 0.9446 - loss: 0.1501 - val_binary_accuracy: 0.9295 - val_loss: 0.1974 - learning_rate: 1.0000e-04
# Epoch 12/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - binary_accuracy: 0.9412 - loss: 0.1486
# Epoch 12: val_binary_accuracy did not improve from 0.92951
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 35s 366ms/step - binary_accuracy: 0.9476 - loss: 0.1429 - val_binary_accuracy: 0.9282 - val_loss: 0.1969 - learning_rate: 1.0000e-04
# Epoch 13/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - binary_accuracy: 0.9495 - loss: 0.1440
# Epoch 13: val_binary_accuracy did not improve from 0.92951
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 35s 368ms/step - binary_accuracy: 0.9481 - loss: 0.1432 - val_binary_accuracy: 0.9275 - val_loss: 0.1941 - learning_rate: 1.0000e-04
# Epoch 14/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - binary_accuracy: 0.9525 - loss: 0.1264
# Epoch 14: val_binary_accuracy did not improve from 0.92951
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 35s 369ms/step - binary_accuracy: 0.9527 - loss: 0.1290 - val_binary_accuracy: 0.9275 - val_loss: 0.1908 - learning_rate: 1.0000e-04
# Epoch 15/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - binary_accuracy: 0.9535 - loss: 0.1205
# Epoch 15: val_binary_accuracy improved from 0.92951 to 0.93347, saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
#
# Epoch 15: finished saving model to C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.keras
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 37s 387ms/step - binary_accuracy: 0.9512 - loss: 0.1254 - val_binary_accuracy: 0.9335 - val_loss: 0.1921 - learning_rate: 1.0000e-04
# Epoch 16/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - binary_accuracy: 0.9582 - loss: 0.1202
# Epoch 16: val_binary_accuracy did not improve from 0.93347
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 35s 368ms/step - binary_accuracy: 0.9581 - loss: 0.1165 - val_binary_accuracy: 0.9256 - val_loss: 0.1946 - learning_rate: 1.0000e-04
# Epoch 17/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - binary_accuracy: 0.9677 - loss: 0.1004
# Epoch 17: val_binary_accuracy did not improve from 0.93347
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 35s 367ms/step - binary_accuracy: 0.9657 - loss: 0.1021 - val_binary_accuracy: 0.9269 - val_loss: 0.1946 - learning_rate: 1.0000e-04
# Epoch 18/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - binary_accuracy: 0.9638 - loss: 0.1007
# Epoch 18: val_binary_accuracy did not improve from 0.93347
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 34s 355ms/step - binary_accuracy: 0.9636 - loss: 0.0997 - val_binary_accuracy: 0.9262 - val_loss: 0.1934 - learning_rate: 1.0000e-04
# Epoch 19/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - binary_accuracy: 0.9662 - loss: 0.0899
# Epoch 19: val_binary_accuracy did not improve from 0.93347
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 34s 354ms/step - binary_accuracy: 0.9649 - loss: 0.0944 - val_binary_accuracy: 0.9275 - val_loss: 0.1928 - learning_rate: 1.0000e-04
# Epoch 20/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - binary_accuracy: 0.9647 - loss: 0.1018
# Epoch 20: val_binary_accuracy did not improve from 0.93347
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 34s 359ms/step - binary_accuracy: 0.9655 - loss: 0.0946 - val_binary_accuracy: 0.9262 - val_loss: 0.1930 - learning_rate: 5.0000e-05
# Epoch 21/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - binary_accuracy: 0.9709 - loss: 0.0877
# Epoch 21: val_binary_accuracy did not improve from 0.93347
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 34s 355ms/step - binary_accuracy: 0.9673 - loss: 0.0915 - val_binary_accuracy: 0.9282 - val_loss: 0.1912 - learning_rate: 5.0000e-05
# Epoch 22/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - binary_accuracy: 0.9689 - loss: 0.0820
# Epoch 22: val_binary_accuracy did not improve from 0.93347
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 34s 354ms/step - binary_accuracy: 0.9662 - loss: 0.0864 - val_binary_accuracy: 0.9256 - val_loss: 0.1930 - learning_rate: 5.0000e-05
# Epoch 23/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - binary_accuracy: 0.9684 - loss: 0.0858
# Epoch 23: val_binary_accuracy did not improve from 0.93347
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 34s 355ms/step - binary_accuracy: 0.9723 - loss: 0.0799 - val_binary_accuracy: 0.9282 - val_loss: 0.1948 - learning_rate: 5.0000e-05
# Epoch 24/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - binary_accuracy: 0.9720 - loss: 0.0803
# Epoch 24: val_binary_accuracy did not improve from 0.93347
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 34s 356ms/step - binary_accuracy: 0.9725 - loss: 0.0796 - val_binary_accuracy: 0.9315 - val_loss: 0.1945 - learning_rate: 5.0000e-05
# Epoch 25/30
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - binary_accuracy: 0.9677 - loss: 0.0824
# Epoch 25: val_binary_accuracy did not improve from 0.93347
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 34s 355ms/step - binary_accuracy: 0.9710 - loss: 0.0776 - val_binary_accuracy: 0.9308 - val_loss: 0.1939 - learning_rate: 2.5000e-05
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# CPU times: total: 1h 24min 36s
# Wall time: 14min 53s

# %% [markdown]
# ---
# ## 14. 학습 곡선

# %%
plt.figure(figsize=(6, 10))

plt.subplot(2, 1, 1)
plt.title('Binary Accuracy')
plt.plot(history.history['binary_accuracy'],     'b', label='train')
plt.plot(history.history['val_binary_accuracy'], 'g', label='val')
plt.axhline(0.80, color='r', linestyle='--', label='KPI 80%')
plt.grid(True)
plt.ylabel('Accuracy')
plt.legend(loc='best')

plt.subplot(2, 1, 2)
plt.title('Loss')
plt.plot(history.history['loss'],     'b', label='train')
plt.plot(history.history['val_loss'], 'g', label='val')
plt.grid(True)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 15. Best 모델 로딩 & 결과 시각화

# %%
model_best = tf.keras.models.load_model(
    saved_model_name,
)
y_out = model_best.predict(test_data)
Make_Result_Plot("After Training", test_data, test_labels, y_out)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 344ms/step

# %% [markdown]
# ---
# ## 16. 혼동행렬 & KPI 확인

# %%
THRESHOLD = 0.6

y_pred      = model_best.predict(test_data)
helmet_true = test_labels[:, 0].astype(int)
helmet_pred = (y_pred[:, 0] >= THRESHOLD).astype(int)
vest_true   = test_labels[:, 1].astype(int)
vest_pred   = (y_pred[:, 1] >= THRESHOLD).astype(int)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for ax, true, pred, title in zip(
    axes,
    [helmet_true, vest_true],
    [helmet_pred, vest_pred],
    ['Helmet (1=착용, 0=미착용)', 'Vest (1=착용, 0=미착용)']
):
    cm   = confusion_matrix(true, pred, labels=[1, 0])
    disp = ConfusionMatrixDisplay(cm, display_labels=['착용(1)', '미착용(0)'])
    disp.plot(ax=ax, colorbar=False)
    ax.set_title(title)

plt.suptitle(f'Confusion Matrix  (threshold={THRESHOLD})', fontsize=13)
plt.tight_layout()
plt.show()

h_acc = (helmet_true == helmet_pred).mean()
v_acc = (vest_true   == vest_pred).mean()
print(f"헬멧 정확도: {h_acc*100:.1f}%   (KPI ≥ 80%)  {'✅' if h_acc>=0.8 else '❌'}")
print(f"조끼 정확도: {v_acc*100:.1f}%   (KPI ≥ 80%)  {'✅' if v_acc>=0.8 else '❌'}")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 7s 305ms/step
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\1509471602.py:22: UserWarning: Glyph 52265 (\N{HANGUL SYLLABLE CAG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\1509471602.py:22: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\1509471602.py:22: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52265 (\N{HANGUL SYLLABLE CAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 헬멧 정확도: 93.1%   (KPI ≥ 80%)  ✅
# 조끼 정확도: 91.3%   (KPI ≥ 80%)  ✅

# %% [markdown]
# ---
# ## 17. 오답 이미지 모아보기

# %%
def show_wrong_predictions(data, true_labels, pred_probs, threshold=0.6, max_show=20):
    wrong_idx = []
    for i in range(len(data)):
        h_true = int(true_labels[i][0])
        v_true = int(true_labels[i][1])
        h_pred = int(pred_probs[i][0] >= threshold)
        v_pred = int(pred_probs[i][1] >= threshold)
        if h_true != h_pred or v_true != v_pred:
            wrong_idx.append(i)

    print(f"전체 {len(data)}장 중 오답: {len(wrong_idx)}장")
    print(f"오답률: {len(wrong_idx)/len(data)*100:.1f}%")

    show_idx = wrong_idx[:max_show]
    n_cols   = 5
    n_rows   = max((len(show_idx) + n_cols - 1) // n_cols, 1)

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, n_rows * 4))
    axes = np.array(axes).flatten()
    fig.suptitle(f"오답 이미지 (총 {len(wrong_idx)}장 중 {len(show_idx)}장)", fontsize=14)

    for ax_idx, i in enumerate(show_idx):
        axes[ax_idx].imshow(data[i])
        h_t = int(true_labels[i][0])
        v_t = int(true_labels[i][1])
        h_p = float(pred_probs[i][0])
        v_p = float(pred_probs[i][1])
        axes[ax_idx].set_title(
            f"정답 H={h_t} V={v_t}\n예측 H={int(h_p>=threshold)}({h_p:.2f}) V={int(v_p>=threshold)}({v_p:.2f})",
            fontsize=8, color='red'
        )
        axes[ax_idx].axis('off')

    for ax_idx in range(len(show_idx), len(axes)):
        axes[ax_idx].axis('off')

    plt.tight_layout()
    plt.show()

show_wrong_predictions(test_data, test_labels, y_pred)
# Out:
# 전체 759장 중 오답: 117장
# 오답률: 15.4%
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\3564034342.py:37: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\3564034342.py:37: UserWarning: Glyph 45813 (\N{HANGUL SYLLABLE DAB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\3564034342.py:37: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\3564034342.py:37: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\3564034342.py:37: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\3564034342.py:37: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\3564034342.py:37: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\3564034342.py:37: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\3564034342.py:37: UserWarning: Glyph 52509 (\N{HANGUL SYLLABLE CONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\3564034342.py:37: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Local\Temp\ipykernel_1232\3564034342.py:37: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45813 (\N{HANGUL SYLLABLE DAB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51648 (\N{HANGUL SYLLABLE JI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52509 (\N{HANGUL SYLLABLE CONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51109 (\N{HANGUL SYLLABLE JANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KCCISTC\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51473 (\N{HANGUL SYLLABLE JUNG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ---
# ## 18. TFLite 변환
# ### 18-A. Float32

# %%
converter    = tf.lite.TFLiteConverter.from_keras_model(model_best)
tflite_model = converter.convert()

tflite_path = os.path.join(save_dir, 'PPE_MobileNetV3Large.tflite')
with open(tflite_path, 'wb') as f:
    f.write(tflite_model)
print(f"TFLite 저장: {tflite_path}")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\KCCISTC\AppData\Local\Temp\tmpa8_4fkik\assets
# INFO:tensorflow:Assets written to: C:\Users\KCCISTC\AppData\Local\Temp\tmpa8_4fkik\assets
# Saved artifact at 'C:\Users\KCCISTC\AppData\Local\Temp\tmpa8_4fkik'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_6')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   1772495934416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495940560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495932688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495932880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495934032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495935376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495932112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425875984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495933840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495931920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425875792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425878096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425875216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425875024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425880976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425873872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425875408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425873296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425872720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425875600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425873104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425873488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425874064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425874256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425873680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425874832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425871952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425881360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425879824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425872912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425877136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425874640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425879248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425880208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425874448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425879440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425880784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425881744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425880592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425878864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425880400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425881936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425882320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425882128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425879056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425882512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425878672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425883280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425883088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425877520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425883472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425882896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425884240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425884048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425882704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425884432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425885008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425883664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425881552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425876176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425883856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425884816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425884624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425881168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428835344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428834384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428836112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428835920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428834576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428836304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428835728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428837072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428836880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428835536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428837264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428837840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428836496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428838224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428837456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428838032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428838800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428838608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428836688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428838992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428838416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428839760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428839568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428837648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428839952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428839376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428840720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428840528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428839184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428840912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428841488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428840144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428841872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428841104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428841680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428842448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428842256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428840336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428842640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428842064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428843408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428843216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428841296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428843600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428843024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428844368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428844176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428842832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428844560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428843984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428845328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428845136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428843792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428845520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428844944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428846288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428846096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428844752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428846480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428845904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428847248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428847056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428845712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428847440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428846864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428848208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428848016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428846672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428848400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428847824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428849168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428848976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428847632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428849360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428848784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428850128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428849936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428848592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428850320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428834960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428850512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428834768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428835152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428849552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646726352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646726544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428849744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646725200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646726736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646725968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646727504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646727312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646726160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646727696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646727120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646728464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646728272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646726928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646728656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646728080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646729424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646729232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646727888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646729616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646729040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646730384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646730192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646728848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646730576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646731152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646729808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646731536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646730768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646731344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646732112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646731920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646730000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646732304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646731728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646733072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646732880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646730960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646733264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646732688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646734032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646733840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646732496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646734224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646734800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646733456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646735184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646734416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646734992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646735760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646735568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646733648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646735952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646735376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646736720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646736528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646734608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646736912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646736336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646737680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646737488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646736144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646737872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646738448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646737104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646738832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646738064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646738640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646739408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646739216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646737296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646739600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646739024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646740368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646740176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646738256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646740560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646739984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646741328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646741136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646739792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646725776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646740944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646725392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646725584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646740752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647004304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647005264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647005072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647004496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647005456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647004880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647006224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647006032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647004688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647006416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647005840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647007184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647006992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647005648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647007376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647007952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647006608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647008336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647007568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647008144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647008912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647008720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647006800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647009104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647008528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647009872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647009680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647007760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647010064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647010640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647010832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647011024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647009296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647009488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647004112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647011984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647003920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647012560: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite 저장: C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large.tflite

# %% [markdown]
# ### 18-B. INT8 양자화 (Raspberry Pi 5 최적화)

# %%
calib_data = test_data[:100].astype(np.float32)

def representative_dataset():
    for img in calib_data:
        yield [img[np.newaxis, ...]]

conv_int8 = tf.lite.TFLiteConverter.from_keras_model(model_best)
conv_int8.optimizations                    = [tf.lite.Optimize.DEFAULT]
conv_int8.target_spec.supported_ops        = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
conv_int8.inference_input_type             = tf.int8
conv_int8.inference_output_type            = tf.int8
conv_int8.representative_dataset           = representative_dataset

tflite_int8 = conv_int8.convert()
int8_path   = os.path.join(save_dir, 'PPE_MobileNetV3Large_INT8.tflite')
with open(int8_path, 'wb') as f:
    f.write(tflite_int8)
print(f"INT8 TFLite 저장: {int8_path}")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\KCCISTC\AppData\Local\Temp\tmpg3peqe5k\assets
# INFO:tensorflow:Assets written to: C:\Users\KCCISTC\AppData\Local\Temp\tmpg3peqe5k\assets
# Saved artifact at 'C:\Users\KCCISTC\AppData\Local\Temp\tmpg3peqe5k'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_6')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   1772495934416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495940560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495932688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495932880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495934032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495935376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495932112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425875984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495933840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1772495931920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425875792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425878096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425875216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425875024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425880976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425873872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425875408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425873296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425872720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425875600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425873104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425873488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425874064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425874256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425873680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425874832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425871952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425881360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425879824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425872912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425877136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425874640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425879248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425880208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425874448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425879440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425880784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425881744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425880592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425878864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425880400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425881936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425882320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425882128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425879056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425882512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425878672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425883280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425883088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425877520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425883472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425882896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425884240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425884048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425882704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425884432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425885008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425883664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425881552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425876176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425883856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425884816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425884624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773425881168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428835344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428834384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428836112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428835920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428834576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428836304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428835728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428837072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428836880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428835536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428837264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428837840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428836496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428838224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428837456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428838032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428838800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428838608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428836688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428838992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428838416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428839760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428839568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428837648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428839952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428839376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428840720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428840528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428839184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428840912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428841488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428840144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428841872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428841104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428841680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428842448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428842256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428840336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428842640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428842064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428843408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428843216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428841296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428843600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428843024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428844368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428844176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428842832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428844560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428843984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428845328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428845136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428843792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428845520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428844944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428846288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428846096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428844752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428846480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428845904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428847248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428847056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428845712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428847440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428846864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428848208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428848016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428846672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428848400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428847824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428849168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428848976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428847632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428849360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428848784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428850128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428849936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428848592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428850320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428834960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428850512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428834768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428835152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428849552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646726352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646726544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773428849744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646725200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646726736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646725968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646727504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646727312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646726160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646727696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646727120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646728464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646728272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646726928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646728656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646728080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646729424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646729232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646727888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646729616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646729040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646730384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646730192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646728848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646730576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646731152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646729808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646731536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646730768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646731344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646732112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646731920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646730000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646732304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646731728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646733072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646732880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646730960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646733264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646732688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646734032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646733840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646732496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646734224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646734800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646733456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646735184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646734416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646734992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646735760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646735568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646733648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646735952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646735376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646736720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646736528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646734608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646736912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646736336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646737680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646737488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646736144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646737872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646738448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646737104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646738832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646738064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646738640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646739408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646739216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646737296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646739600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646739024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646740368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646740176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646738256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646740560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646739984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646741328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646741136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646739792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646725776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646740944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646725392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646725584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773646740752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647004304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647005264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647005072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647004496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647005456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647004880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647006224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647006032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647004688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647006416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647005840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647007184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647006992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647005648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647007376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647007952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647006608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647008336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647007568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647008144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647008912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647008720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647006800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647009104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647008528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647009872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647009680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647007760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647010064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647010640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647010832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647011024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647009296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647009488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647004112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647011984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647003920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1773647012560: TensorSpec(shape=(), dtype=tf.resource, name=None)
# c:\Users\KCCISTC\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\lite\python\convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# INT8 TFLite 저장: C:\Users\KCCISTC\Desktop\train_sampled-20260514T075558Z-3-001\train_sampled\PPE_MobileNetV3Large_INT8.tflite

# %% [markdown]
# ---
# ## 19. 로컬 PC 다운로드

# %%
# ─────────────────────────────────────────────────────────
# 17. 로컬 PC로 다운로드 (드라이브에도 이미 저장되어 있음)
# ─────────────────────────────────────────────────────────
from google.colab import files

download_list = [
    'PPE_MobileNetV3Large.keras',        # keras 베스트 모델
    'PPE_MobileNetV3Large.tflite',       # Float32 TFLite
    'PPE_MobileNetV3Large_INT8.tflite',  # INT8 TFLite (Pi5용)
]

print("=" * 45)
print("📦 저장 파일 다운로드 시작")
print(f"📂 드라이브 저장 경로: {save_dir}")
print("=" * 45)

for fname in download_list:
    fpath = os.path.join(save_dir, fname)
    if os.path.exists(fpath):
        size_mb = os.path.getsize(fpath) / (1024 * 1024)
        print(f"⬇️  다운로드 중: {fname}  ({size_mb:.1f} MB)")
        files.download(fpath)
    else:
        print(f"⚠️  파일 없음 — 16번 셀(TFLite 변환)을 먼저 실행하세요: {fname}")

print("\n✅ 다운로드 완료! 드라이브 + 로컬 PC 양쪽에 저장됐어요.")

# %% [markdown]
# ---
# ## 20. 추론 함수 (Raspberry Pi 5 복사 사용)
# > `detector.py`에 그대로 붙여넣어 사용

# %%
def run_ppe_inference(interpreter, img_bgr, threshold=0.3):
    """
    Parameters
    ----------
    interpreter : tf.lite.Interpreter  (allocate_tensors() 완료)
    img_bgr     : np.ndarray  OpenCV BGR 이미지
    threshold   : float  착용 판정 임계값 (기본 0.3)

    Returns
    -------
    dict {helmet, vest, helmet_prob, vest_prob}
    """
    inp_d = interpreter.get_input_details()
    out_d = interpreter.get_output_details()

    img_rgb   = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    img_sized = cv2.resize(img_rgb, (IMG_SIZE, IMG_SIZE)).astype(np.float32)
    img_input = img_sized[np.newaxis, ...]

    interpreter.set_tensor(inp_d[0]['index'], img_input)
    interpreter.invoke()
    output = interpreter.get_tensor(out_d[0]['index'])[0]

    return {
        'helmet'      : bool(output[0] >= threshold),
        'vest'        : bool(output[1] >= threshold),
        'helmet_prob' : float(output[0]),
        'vest_prob'   : float(output[1]),
    }

# 동작 확인
interp = tf.lite.Interpreter(model_content=tflite_model)
interp.allocate_tensors()

sample_bgr = cv2.cvtColor(test_data[0], cv2.COLOR_RGB2BGR)
result     = run_ppe_inference(interp, sample_bgr)

print("추론 결과 :", result)
print(f"실제 라벨 : helmet={int(test_labels[0][0])}, vest={int(test_labels[0][1])}")
